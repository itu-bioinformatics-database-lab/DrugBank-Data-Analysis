# %%
# Parsing drugbank database with XML ElementTree
import xml.etree.ElementTree as ET

# %%
tree = ET.parse("full database.xml")
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://www.drugbank.ca}drugbank'

# %%
root
# Out:
# <Element '{http://www.drugbank.ca}drugbank' at 0x0000028943068BD0>

# %%
root.attrib
# Out:
# {'{http://www.w3.org/2001/XMLSchema-instance}schemaLocation': 'http://www.drugbank.ca http://www.drugbank.ca/docs/drugbank.xsd',
#  'version': '5.1',
#  'exported-on': '2021-01-03'}

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# {http://www.drugbank.ca}drug {'type': 'biotech', 'created': '2005-06-13', 'updated': '2020-11-02'}
# {http://www.drugbank.ca}drug {'type': 'biotech', 'created': '2005-06-13', 'updated': '2021-01-01'}
# {http://www.drugbank.ca}drug {'type': 'biotech', 'created': '2005-06-13', 'updated': '2021-01-01'}
# {http://www.drugbank.ca}drug {'type': 'biotech', 'created': '2005-06-13', 'updated': '2020-09-03'}
# {http://www.drugbank.ca}drug {'type': 'biotech', 'created': '2005-06-13', 'updated': '2021-01-01'}
# {http://www.drugbank.ca}drug {'type': 'small molecule', 'created': '2005-06-13', 'updated': '2021-01-01'}
# {http://www.drugbank.ca}drug {'type': 'small molecule', 'created': '2005-06-13', 'updated': '2021-01-01'}
# {http://www.drugbank.ca}drug {'type': 'biotech', 'created': '2005-06-13', 'updated': '2021-01-01'}
# {http://www.drugbank.ca}drug {'type': 'biotech', 'created': '2005-06-13', 'updated': '2021-01-01'}
# ...

# %%
from lxml import etree
