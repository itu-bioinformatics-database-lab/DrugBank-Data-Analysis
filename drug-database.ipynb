# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_xml("full database.xml")
df.head(15)
# Out:
#               type     created     updated  \
# 0          biotech  2005-06-13  2020-11-02
# 1          biotech  2005-06-13  2021-01-01
# 2          biotech  2005-06-13  2021-01-01
# 3          biotech  2005-06-13  2020-09-03
# 4          biotech  2005-06-13  2021-01-01
# 5   small molecule  2005-06-13  2021-01-01
# 6   small molecule  2005-06-13  2021-01-01
# 7          biotech  2005-06-13  2021-01-01
# 8          biotech  2005-06-13  2021-01-01
# 9          biotech  2005-06-13  2020-09-03
# 10         biotech  2005-06-13  2020-09-03
# 11         biotech  2005-06-13  2021-01-01
# 12         biotech  2005-06-13  2020-11-02
# 13  small molecule  2005-06-13  2021-01-01
# 14         biotech  2005-06-13  2020-12-24
#
#    {http://www.drugbank.ca}drugbank-id {http://www.drugbank.ca}name  \
# 0                            BIOD00024                    Lepirudin
# 1                            BIOD00071                    Cetuximab
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14315 entries, 0 to 14314
# Data columns (total 58 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   type                                                14315 non-null  object
#  1   created                                             14315 non-null  object
#  2   updated                                             14315 non-null  object
#  3   {http://www.drugbank.ca}drugbank-id                 14315 non-null  object
#  4   {http://www.drugbank.ca}name                        14315 non-null  object
#  5   {http://www.drugbank.ca}description                 8399 non-null   object
#  6   {http://www.drugbank.ca}cas-number                  8943 non-null   object
#  7   {http://www.drugbank.ca}unii                        9914 non-null   object
# ...

# %%
df.to_csv("drugbank-database-pandas.csv", index=False, header=True)
